# %% [markdown]
# # Demo Inference Script for MV-DUSt3R+ with Estimated-Depth Correction
#
# This notebook extracts 4 visualizations for qualitative analysis:
# 1. `mvdust3r_only.glb` (Raw MV-DUSt3R+ point cloud)
# 2. `depth_backprojection.glb` (Direct depth-only cloud)
# 3. `corrected_final.glb` (MV-DUSt3R+ corrected by fine-tuned depth)
# 4. `depth_maps/*.png` and `comparisons/*.png` (Colorized depth outputs)
#
# **Requirements before running:**
# - Set Accelerator to **GPU T4 x2**
# - Mount the `scannet-data` dataset
# - Mount the **Run 37** output dataset (`mv-dust3r-run-37-depth-full-fine-tune`)

# %%
# 1. Clone repository and checkout the new branch
# !git clone https://github.com/NguyenNgocMinh30012005/Computer_vision_2025.2.git
# %cd Computer_vision_2025.2
# !git checkout feature/demo-inference-script

# %%
import os

# 2. Configure environment variables for the demo
os.environ['DEMO_SCENE'] = 'scene0000_00'  # Change to any scene you want to test
os.environ['DEMO_NUM_VIEWS'] = '5'
os.environ['DEMO_TAU'] = '0.30'
os.environ['DEMO_ALPHA'] = '1.0'
# os.environ['DEMO_FRAMES'] = '00000.jpg,00050.jpg,00100.jpg,00150.jpg,00200.jpg' # Uncomment to manually pick frames

# Run the script
# !python scripts/kaggle/kaggle_demo_inference.py

# %%
# 3. Zip the outputs so they are easy to download from Kaggle
# !zip -r /kaggle/working/demo_outputs.zip /kaggle/working/outputs/demo_inference
